# %% [markdown]
# # 5.1 Synthetic Data Generation
#
# ## Ziel
# Generierung synthetischer Datensätze basierend auf dem trainierten VAE-Modell aus Schritt 4.1.
#
# ## Vorgehen
# 1. **Modell Laden:** Das trainierte VAE-Modell laden.
# 2. **Sampling:** Ziehen von Stichproben aus dem Latent Space (Standardnormalverteilung).
# 3. **Decoding:** Generierung neuer Datenpunkte durch den Decoder.
# 4. **Validierung:** Vergleich der Verteilungen (Real vs. Synthetic).

# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
from pathlib import Path

# - Reproduzierbarkeit
torch.manual_seed(42)
np.random.seed(42)
