# %% [markdown]
# <div class="alert alert-info">
#     <b>1.3 Datenqualität: Manuelle Eingabe (Spezifische Spalten)</b><br>
#     Dieses Notebook analysiert den Ionenbilanzfehler (IBE) basierend auf einer manuellen Konfiguration.<br>
#     -> Erlaubt die exakte Zuweisung von Spalten für jede Datenbank<br>
#     -> Umgeht Probleme der automatischen Erkennung bei schlecht benannten Spalten<br>
#     -> Nutzt Standard-Valenzen für die Berechnung
# </div>
