# %%
from pathlib import Path
import importlib

import core_processing
importlib.reload(core_processing)

from core_processing import process_excel_to_csv

# -----------------------------------------------------------------------------------------------

# Left side HAS to be lowercase | only allowing "_" and "-" for special characters
# Left side features excel-column namnes

# Right side features column names from global data scheme

mapping_db = {
    "place": "location",
    "well_name": "well_or_spring_name",
    # ...
    # ...
}

# -----------------------------------------------------------------------------------------------

# Change paramters for data to be used

process_excel_to_csv(
    input_xlsx="my_input.xlsx",    # should be located in "Input_formatted_xlsx"
    output_csv="my_output.csv",    # will be located in "Output_cleaned_csv" 
    sheet_name="Daten",            # Sheet Name from excel to be used
    mapping=mapping_db,
)

# -----------------------------------------------------

"""
Attributes to be used for mapping
    "location",
    "well_or_spring_name",
    "WGS84_latitude",
    "WGS84_longitude",
    "depth_bgl_in_m",
    "rock_type",
    "stratigraphic_period",
    "temperature_in_c",
    "electrical_conductivity_25c_in_uS/cm",
    "pH",
    "redox_potential_in_mV",
    "total_dissolved_solids_in_mmol/L", 
    "O2_in_mmol/L",
    "Na_in_mmol/L",
    "Mg_in_mmol/L",
    "Ca_in_mmol/L",
    "Cl_in_mmol/L",
    "SO4_in_mmol/L",
    "HCO3_in_mmol/L",
    "Li_in_mmol/L",
    "K_in_mmol/L",
    "Sr_in_umol/L", # umol
    "NH4_in_umol/L", # umol
    "Fe_in_mmol/L",
    "Mn_in_mmol/L",
    "F_in_umol/L", # umol
    "NO3_in_mmol/L",
    "H2SiO3_in_umol/L", # umol
    "HS_in_mmol/L",
    "Database_number",
    "Database_name"
"""
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 18
#       7 from core_processing import process_excel_to_csv
#       9 mapping_db = {
#      10     "sample_id": "Sample_ID",
#      11     "temperature_c": "Temperature_degC",
#      12     # ...
#      13 }
# ---> 18 process_excel_to_csv(
#      19     input_xlsx="my_input.xlsx",    # should be located in "Input_formatted_xlsx"
#      20     output_csv="my_output.csv",    # will be located in "Output_cleaned_csv"
#      21     sheet_name="Daten",            # Sheet Name from excel to be used
#      22     mapping=mapping_db,
#      23 )
#      25 # -----------------------------------------------------
#
# ...
